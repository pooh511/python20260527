# %%
#jupyter 노트북 개발환경(셀 단위 실행)
#라이브러리 불러오기
# %matplotlib inline
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

plt.plot(np.arange(10))
#cell 단위 실행은 shift + enter

# %%
#판다스 선언 예시
import pandas as pd
from pandas import Series, DataFrame

#series 형식을 사용
myCampus = Series([100, 200, 300, 400, 500],
                  index = ["2026-05-01", "2026-05-02", "2026-05-03", "2026-05-04", "2026-05-05"])

# 슬라이싱
myCampus["2026-05-01"]
# Out:
# np.int64(100)

# %%
data = {"foreigner": [1,2,3,4,5,6],
        "sratio":[10,20,30,40,50,60],
        "org":[100,200,300,400,500,600],
        "spice":[1,2,3,4,5,6],
        "private":[10,20,30,40,50,60]
        }



df = DataFrame(data, 
               columns = ["private", "org","foreigner","sratio","spice"],
               index = ["2026-05-01", "2026-05-02", "2026-05-03", "2026-05-04", "2026-05-05", "2026-05-06"])

#특정컬럼을 슬라이싱 하기
df["private"]

print(df.loc["2026-05-02"])

#!를 붙이면 플랫폼 명령어 실행
# !type c:\work\ex1.csv
# Out:
# private       20
# org          200
# foreigner      2
# sratio        20
# spice          2
# Name: 2026-05-02, dtype: int64
# id, name, price, description
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
#데이터 프레임으로 로딩
df2 = pd.read_csv("c:/work/ex1.csv")
df2
# Out:
#    id       name    price           description
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
#2번파일
# !type c:\work\ex2.csv
# Out:
# 1, iphone, 1990000, iphone 17
# 2, android, 1590000, samsung phone
# 3, winphone, 850000, microsoft winphone

# %%
df3 = pd.read_csv("c:/work/ex2.csv", header=None,
                  names=["id", "name", "price", "desc"])
df3
# Out:
#    id       name    price                  desc
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000         samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
#3번파일
# !type c:\work\ex3.csv
# Out:
# data1 data2 data3
# 1.2 2.3 1.3
# 0.1 1.5 2.5
# 3.1 3.2 3.3

# %%
#공백문자를 구분자
df4 = pd.read_table(r"c:/work/ex3.csv", sep="\s+")
df4
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\student\AppData\Local\Temp\ipykernel_17144\2705292897.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df4 = pd.read_table(r"c:/work/ex3.csv", sep="\s+")
#    data1  data2  data3
# 0    1.2    2.3    1.3
# 1    0.1    1.5    2.5
# 2    3.1    3.2    3.3

# %%
# !type c:\work\ex1.csv
# Out:
# id:: name:: price:: description
# 1:: iphone:: 1990000:: iphone 17
# 2:: android:: 1590000:: samsung phone
# 3:: winphone:: 850000:: microsoft winphone

# %%
dfresult = pd.read_csv("c:/work/ex1.csv", sep ="::")
dfresult
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_17144\1168924378.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   dfresult = pd.read_csv("c:/work/ex1.csv", sep ="::")
#    id       name    price          description
# 0   1     iphone  1990000            iphone 17
# 1   2    android  1590000        samsung phone
# 2   3   winphone   850000   microsoft winphone

# %%
#declare
import matplotlib.pyplot as plt

#엑셀파일 로딩
dfExcel = pd.read_excel(r"c:/work/demo.xlsx",sheet_name="Sheet1")
#chart 그리기
fig = plt.figure()
#1행,1열,1번챠트
ax = fig.add_subplot(1,1,1)
#히스토그램 그리기
ax.hist(dfExcel["나이"], bins=5)
# Out:
# (array([1., 3., 3., 2., 1.]),
#  array([26. , 29.6, 33.2, 36.8, 40.4, 44. ]),
#  <BarContainer object of 5 artists>)
